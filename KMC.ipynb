# %%
import numpy as np
import sklearn

# %%
from sklearn.preprocessing import scale
from sklearn.cluster import KMeans

# %%
import pandas as pd

# %%
pd.read_csv("agr_en_train.csv")
# Out:
#        facebook_corpus_msr_1723796  \
# 0       facebook_corpus_msr_466073
# 1      facebook_corpus_msr_1493901
# 2       facebook_corpus_msr_405512
# 3      facebook_corpus_msr_1521685
# 4       facebook_corpus_msr_462570
# ...                            ...
# 11993   facebook_corpus_msr_394638
# 11994   facebook_corpus_msr_429177
# 11995  facebook_corpus_msr_2032370
# 11996  facebook_corpus_msr_1722926
# 11997   facebook_corpus_msr_327960
#
#       Well said sonu..you have courage to stand against dadagiri of Muslims  \
# 0      Most of Private Banks ATM's Like HDFC, ICICI e...
# 1         Now question is, Pakistan will adhere to this?
# 2      Pakistan is comprised of fake muslims who does...
# 3      ??we r against cow slaughter,so of course it w...
# 4      Wondering why Educated Ambassador is strugglin...
# ...                                                  ...
# 11993  They belong to you flight dirty terrorist coun...
# ...

# %%
df = pd.DataFrame(pd.read_csv("agr_en_train.csv"))

# %%
df
# Out:
#        facebook_corpus_msr_1723796  \
# 0       facebook_corpus_msr_466073
# 1      facebook_corpus_msr_1493901
# 2       facebook_corpus_msr_405512
# 3      facebook_corpus_msr_1521685
# 4       facebook_corpus_msr_462570
# ...                            ...
# 11993   facebook_corpus_msr_394638
# 11994   facebook_corpus_msr_429177
# 11995  facebook_corpus_msr_2032370
# 11996  facebook_corpus_msr_1722926
# 11997   facebook_corpus_msr_327960
#
#       Well said sonu..you have courage to stand against dadagiri of Muslims  \
# 0      Most of Private Banks ATM's Like HDFC, ICICI e...
# 1         Now question is, Pakistan will adhere to this?
# 2      Pakistan is comprised of fake muslims who does...
# 3      ??we r against cow slaughter,so of course it w...
# 4      Wondering why Educated Ambassador is strugglin...
# ...                                                  ...
# 11993  They belong to you flight dirty terrorist coun...
# ...

# %%
df.pop(1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 1
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df = df.iloc[:,1:]

# %%
df
# Out:
#       Well said sonu..you have courage to stand against dadagiri of Muslims  \
# 0      Most of Private Banks ATM's Like HDFC, ICICI e...
# 1         Now question is, Pakistan will adhere to this?
# 2      Pakistan is comprised of fake muslims who does...
# 3      ??we r against cow slaughter,so of course it w...
# 4      Wondering why Educated Ambassador is strugglin...
# ...                                                  ...
# 11993  They belong to you flight dirty terrorist coun...
# 11994  Really motivating programme, congratulations t...
# 11995                                    fabricated news
# 11996               What's wrong with you secular idiots
# 11997  Looks like inevitable after all political hard...
#
#        OAG
# 0      NAG
# 1      OAG
# 2      OAG
# 3      NAG
# 4      CAG
# ...    ...
# 11993  OAG
# 11994  NAG
# 11995  OAG
# 11996  OAG
# 11997  NAG
#
# [11998 rows x 2 columns]

# %%
df[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 2
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df["oag"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'oag'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df.describe()
# Out:
#        Well said sonu..you have courage to stand against dadagiri of Muslims  \
# count                                               11998
# unique                                              11643
# top     Gandhi Killer Ram (Nathu) Temple in India........
# freq                                                   14
#
#           OAG
# count   11998
# unique      3
# top       NAG
# freq     5051

# %%
df.coloumns = ["text","offensive"]
# Out:
# C:\Users\Madhu\AppData\Local\Temp/ipykernel_17228/573664633.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.coloumns = ["text","offensive"]

# %%
df
# Out:
#       Well said sonu..you have courage to stand against dadagiri of Muslims  \
# 0      Most of Private Banks ATM's Like HDFC, ICICI e...
# 1         Now question is, Pakistan will adhere to this?
# 2      Pakistan is comprised of fake muslims who does...
# 3      ??we r against cow slaughter,so of course it w...
# 4      Wondering why Educated Ambassador is strugglin...
# ...                                                  ...
# 11993  They belong to you flight dirty terrorist coun...
# 11994  Really motivating programme, congratulations t...
# 11995                                    fabricated news
# 11996               What's wrong with you secular idiots
# 11997  Looks like inevitable after all political hard...
#
#        OAG
# 0      NAG
# 1      OAG
# 2      OAG
# 3      NAG
# 4      CAG
# ...    ...
# 11993  OAG
# 11994  NAG
# 11995  OAG
# 11996  OAG
# 11997  NAG
#
# [11998 rows x 2 columns]

# %%
df.coloumns
# Out:
# ['text', 'offensive']

# %%
df
# Out:
#       Well said sonu..you have courage to stand against dadagiri of Muslims  \
# 0      Most of Private Banks ATM's Like HDFC, ICICI e...
# 1         Now question is, Pakistan will adhere to this?
# 2      Pakistan is comprised of fake muslims who does...
# 3      ??we r against cow slaughter,so of course it w...
# 4      Wondering why Educated Ambassador is strugglin...
# ...                                                  ...
# 11993  They belong to you flight dirty terrorist coun...
# 11994  Really motivating programme, congratulations t...
# 11995                                    fabricated news
# 11996               What's wrong with you secular idiots
# 11997  Looks like inevitable after all political hard...
#
#        OAG
# 0      NAG
# 1      OAG
# 2      OAG
# 3      NAG
# 4      CAG
# ...    ...
# 11993  OAG
# 11994  NAG
# 11995  OAG
# 11996  OAG
# 11997  NAG
#
# [11998 rows x 2 columns]

# %%
df[]
# Out:
#   File "C:\Users\Madhu\AppData\Local\Temp/ipykernel_17228/1951995059.py", line 1
#     df[]
#        ^
# SyntaxError: invalid syntax

# %%
df["text"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'text'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
print(df)
# Out:
#       Well said sonu..you have courage to stand against dadagiri of Muslims  \
# 0      Most of Private Banks ATM's Like HDFC, ICICI e...
# 1         Now question is, Pakistan will adhere to this?
# 2      Pakistan is comprised of fake muslims who does...
# 3      ??we r against cow slaughter,so of course it w...
# 4      Wondering why Educated Ambassador is strugglin...
# ...                                                  ...
# 11993  They belong to you flight dirty terrorist coun...
# 11994  Really motivating programme, congratulations t...
# 11995                                    fabricated news
# 11996               What's wrong with you secular idiots
# 11997  Looks like inevitable after all political hard...
#
#        OAG
# 0      NAG
# 1      OAG
# 2      OAG
# 3      NAG
# 4      CAG
# ...    ...
# 11993  OAG
# 11994  NAG
# 11995  OAG
# 11996  OAG
# 11997  NAG
#
# [11998 rows x 2 columns]

# %%
df.columns = ["Text","Offensive"]

# %%
df
# Out:
#                                                     Text Offensive
# 0      Most of Private Banks ATM's Like HDFC, ICICI e...       NAG
# 1         Now question is, Pakistan will adhere to this?       OAG
# 2      Pakistan is comprised of fake muslims who does...       OAG
# 3      ??we r against cow slaughter,so of course it w...       NAG
# 4      Wondering why Educated Ambassador is strugglin...       CAG
# ...                                                  ...       ...
# 11993  They belong to you flight dirty terrorist coun...       OAG
# 11994  Really motivating programme, congratulations t...       NAG
# 11995                                    fabricated news       OAG
# 11996               What's wrong with you secular idiots       OAG
# 11997  Looks like inevitable after all political hard...       NAG
#
# [11998 rows x 2 columns]

# %%
data = scale(df["Text"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17228/1373300184.py in <module>
# ----> 1 data = scale(df["Text"])
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_data.py in scale(X, axis, with_mean, with_std, copy)
#     159
#     160     """  # noqa
# --> 161     X = check_array(X, accept_sparse='csc', copy=copy, ensure_2d=False,
#     162                     estimator='the scale function', dtype=FLOAT_DTYPES,
#     163                     force_all_finite='allow-nan')
#
# ...

# %%
df.to_csv("agr_en_train_modified.csv")
