# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\Sarath\Documents\S4\Hackathon\english_test.csv")

# %%
df.describe()
# Out:
#         facebook_corpus_msr_451811  \
# count                         3000
# unique                        3000
# top     facebook_corpus_msr_334368
# freq                             1
#
#        The quality of re made now makes me think it is something to be bought from fish market  \
# count                                                3000
# unique                                               2968
# top                                                  Fake
# freq                                                    5
#
#          CAG
# count   3000
# unique     3
# top      NAG
# freq    1233

# %%
df.columns=["Source","Textual Data","Hate"]

# %%
df.drop(columns=["Source"])
# Out:
#                                            Textual Data Hate
# 0     @siva \r\nHow is ur mother???\r\nHow is ur wif...  NAG
# 1     Also see ....hw ur RSS activist caught in Burk...  NAG
# 2     On the death of 2 jawans in LOC CROSS FIRING\r...  NAG
# 3     Modi ho ya Manmohan singh saala yeh log kuch n...  OAG
# 4     No discrimination in policies and NON protecti...  CAG
# ...                                                 ...  ...
# 2995                     Gaddaron se to yahi sahi hain.  NAG
# 2996  Just saw this news\r\n* read 1dt comment. \r\n...  CAG
# 2997  U guys can crack jokes but can't take the crid...  CAG
# 2998  These media fellows have time to dissect one's...  CAG
# 2999  Middle class is suffering, but most affected a...  NAG
#
# [3000 rows x 2 columns]

# %%
df
# Out:
#                            Source  \
# 0      facebook_corpus_msr_334368
# 1      facebook_corpus_msr_331195
# 2      facebook_corpus_msr_403402
# 3      facebook_corpus_msr_379239
# 4     facebook_corpus_msr_2111264
# ...                           ...
# 2995  facebook_corpus_msr_2111345
# 2996   facebook_corpus_msr_327007
# 2997  facebook_corpus_msr_1600567
# 2998  facebook_corpus_msr_1931139
# 2999   facebook_corpus_msr_470220
#
#                                            Textual Data Hate
# 0     @siva \r\nHow is ur mother???\r\nHow is ur wif...  NAG
# 1     Also see ....hw ur RSS activist caught in Burk...  NAG
# 2     On the death of 2 jawans in LOC CROSS FIRING\r...  NAG
# 3     Modi ho ya Manmohan singh saala yeh log kuch n...  OAG
# 4     No discrimination in policies and NON protecti...  CAG
# ...                                                 ...  ...
# 2995                     Gaddaron se to yahi sahi hain.  NAG
# ...

# %%
# Out:
#                        Source  \
# 1  facebook_corpus_msr_331195
#
#                                         Textual Data Hate
# 1  Also see ....hw ur RSS activist caught in Burk...  NAG
